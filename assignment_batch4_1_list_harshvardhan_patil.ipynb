# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
lst=[20,30,70]
lst.append(80)
lst
# Out:
# [20, 30, 70, 80]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
lst=["apple","strobery","banana","gauva"]
lst.insert(2,"papaya")
lst
# Out:
# ['apple', 'strobery', 'papaya', 'banana', 'gauva']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
lst=["harsh","sanket","sujit"]
lst.pop(0)
lst.remove("sanket")
lst
# Out:
# ['sujit']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
lst=[56,78,96,34]
lst[2]=100
lst
# Out:
# [56, 78, 100, 34]

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
lst=[45,78,90,12,89,77]
lst[0:3]
# Out:
# [45, 78, 90]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
lst=["black","white","pink","blue"]
lst.index("pink")
# Out:
# 2

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
lst=[21,45,78,5,33,66,88,90,23,5]
lst.count(5)
# Out:
# 2

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
lst=[67,77,90,13,23,67,44,88,91]
lst.pop(3)

print("after delete list : ",lst)
# Out:
# after delete list :  [67, 77, 90, 23, 67, 44, 88, 91]

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
lst1=["tiger","goat","lion"]
lst2=["buffalo","cat","dog","cow"]
lst1.extend(lst2)
lst1
# Out:
# ['tiger', 'goat', 'lion', 'buffalo', 'cat', 'dog', 'cow']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
lst=[67,77,90,13,23,67,44,88,91]
lst.pop()
print("after delete last number:",lst)
# Out:
# after delete last number: [67, 77, 90, 13, 23, 67, 44, 88]

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
lst=[21,45,78,5,33,66,88,90,23,5]
lst.sort()
lst
# Out:
# [5, 5, 21, 23, 33, 45, 66, 78, 88, 90]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
lst=["india","china","bangal","shrilanka","afgan"]
lst.sort(reverse=True)
lst
# Out:
# ['shrilanka', 'india', 'china', 'bangal', 'afgan']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
lst=["apple","strobery","banana","gauva"]
lst.count("apple")
# Out:
# 1

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
num = [67, 77, 90, 13, 23, 67, 44, 88, 91]

print("min is:", min(num))
print("max is:", max(num))
# Out:
# min is: 13
# max is: 91

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
lst1=["tiger","goat","lion"]
lst2=[21,45,78,5,33,66,88,90,23,5]
lst1.extend(lst2)
lst1
# Out:
# ['tiger', 'goat', 'lion', 21, 45, 78, 5, 33, 66, 88, 90, 23, 5]

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
num = [67, 77, 90, 13, 23, 67, 44, 88, 91]
num[-1]=29
num
# Out:
# [67, 77, 90, 13, 23, 67, 44, 88, 29]

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
lst=[21,45,78,5,33,66,88,90,23,5]
lst.clear()
lst
# Out:
# []

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
lst=["harsh","patil","sonarwadi"]
new_lst=lst.copy()
new_lst
# Out:
# ['harsh', 'patil', 'sonarwadi']
